# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## EDA

# %%
# import the dataset
dataset_df = pd.read_csv('dataset.csv')

# %%
dataset_df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16 Symptom_17
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# There are 4930 patients

# %%
dataset_df.shape
# Out:
# (4930, 18)

# %%
dataset_df = dataset_df.apply(lambda col: col.str.strip())

# %%
test = pd.get_dummies(dataset_df.filter(regex='Symptom'), prefix='', prefix_sep='')

# %%
test.head()
# Out:
#    acidity  back_pain  bladder_discomfort  breathlessness  \
# 0    False      False               False           False
# 1    False      False               False           False
# 2    False      False               False           False
# 3    False      False               False           False
# 4    False      False               False           False
#
#    burning_micturition  chest_pain  chills  constipation  continuous_sneezing  \
# 0                False       False   False         False                False
# 1                False       False   False         False                False
# 2                False       False   False         False                False
# 3                False       False   False         False                False
# 4                False       False   False         False                False
#
#    cough  ...  congestion  phlegm  red_spots_over_body  blood_in_sputum  \
# 0  False  ...       False   False                False            False
# 1  False  ...       False   False                False            False
# 2  False  ...       False   False                False            False
# 3  False  ...       False   False                False            False
# 4  False  ...       False   False                False            False
#
#    chest_pain  loss_of_smell  blood_in_sputum  loss_of_smell  muscle_pain  \
# 0       False          False            False          False        False
# 1       False          False            False          False        False
# 2       False          False            False          False        False
# 3       False          False            False          False        False
# 4       False          False            False          False        False
#
#    muscle_pain
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 404 columns]

# %%
test = test.groupby(test.columns, axis=1).agg(np.max)
# Out:
# <ipython-input-11-b1f3036612dc>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   test = test.groupby(test.columns, axis=1).agg(np.max)
# <ipython-input-11-b1f3036612dc>:1: FutureWarning: The provided callable <function max at 0x7836d151d120> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   test = test.groupby(test.columns, axis=1).agg(np.max)

# %%
clean_df = pd.merge(test,dataset_df['Disease'], left_index=True, right_index=True)

# %%
clean_df
# Out:
#       abdominal_pain  abnormal_menstruation  acidity  acute_liver_failure  \
# 0              False                  False    False                False
# 1              False                  False    False                False
# 2              False                  False    False                False
# 3              False                  False    False                False
# 4              False                  False    False                False
# ...              ...                    ...      ...                  ...
# 4925           False                  False    False                False
# 4926           False                  False    False                False
# 4927           False                  False    False                False
# 4928           False                  False    False                False
# 4929           False                  False    False                False
#
#       altered_sensorium  anxiety  back_pain  belly_pain  blackheads  \
# 0                 False    False      False       False       False
# 1                 False    False      False       False       False
# 2                 False    False      False       False       False
# 3                 False    False      False       False       False
# 4                 False    False      False       False       False
# ...                 ...      ...        ...         ...         ...
# 4925              False    False      False       False       False
# 4926              False    False      False       False       False
# 4927              False    False      False       False       False
# 4928              False    False      False       False       False
# 4929              False    False      False       False       False
#
#       bladder_discomfort  ...  watering_from_eyes  weakness_in_limbs  \
# 0                  False  ...               False              False
# 1                  False  ...               False              False
# 2                  False  ...               False              False
# 3                  False  ...               False              False
# 4                  False  ...               False              False
# ...                  ...  ...                 ...                ...
# 4925               False  ...               False              False
# 4926               False  ...               False              False
# 4927               False  ...               False              False
# 4928               False  ...               False              False
# 4929               False  ...               False              False
#
#       weakness_of_one_body_side  weight_gain  weight_loss  yellow_crust_ooze  \
# 0                         False        False        False              False
# 1                         False        False        False              False
# 2                         False        False        False              False
# 3                         False        False        False              False
# 4                         False        False        False              False
# ...                         ...          ...          ...                ...
# 4925                      False        False        False              False
# 4926                      False        False        False              False
# 4927                      False        False        False              False
# 4928                      False        False        False              False
# 4929                      False        False        False              False
#
#       yellow_urine  yellowing_of_eyes  yellowish_skin           Disease
# 0            False              False           False  Fungal infection
# 1            False              False           False  Fungal infection
# 2            False              False           False  Fungal infection
# 3            False              False           False  Fungal infection
# 4            False              False           False  Fungal infection
# ...            ...                ...             ...               ...
# 4925         False              False           False             Covid
# 4926         False              False           False             Covid
# 4927         False              False           False             Covid
# 4928         False              False           False             Covid
# 4929         False              False           False             Covid
#
# [4930 rows x 134 columns]

# %%
clean_df.columns.get_loc('acidity')
# Out:
# 2

# %%
test = np.zeros((1,132))

# %%
test[0,12]
# Out:
# 0.0

# %% [markdown]
# Machine learning model: XGBoost random forest classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import preprocessing

# %%
X_data = clean_df.iloc[:,:-1]
y_data = clean_df.iloc[:,-1]

# Convert y to categorical values
y_data = y_data.astype('category')

# %%
X_data.shape
# Out:
# (4930, 133)

# %%
y_data.shape
# Out:
# (4930,)

# %%
le = preprocessing.LabelEncoder()
le.fit(y_data)
# Out:
# LabelEncoder()

# %%
y_data.cat.categories
# Out:
# Index(['(vertigo) Paroymsal  Positional Vertigo', 'AIDS', 'Acne',
#        'Alcoholic hepatitis', 'Allergy', 'Arthritis', 'Bronchial Asthma',
#        'Cervical spondylosis', 'Chicken pox', 'Chronic cholestasis',
#        'Common Cold', 'Covid', 'Dengue', 'Diabetes',
#        'Dimorphic hemmorhoids(piles)', 'Drug Reaction', 'Fungal infection',
#        'GERD', 'Gastroenteritis', 'Heart attack', 'Hepatitis B', 'Hepatitis C',
#        'Hepatitis D', 'Hepatitis E', 'Hypertension', 'Hyperthyroidism',
#        'Hypoglycemia', 'Hypothyroidism', 'Impetigo', 'Jaundice', 'Malaria',
#        'Migraine', 'Osteoarthristis', 'Paralysis (brain hemorrhage)',
#        'Peptic ulcer diseae', 'Pneumonia', 'Psoriasis', 'Tuberculosis',
#        'Typhoid', 'Urinary tract infection', 'Varicose veins', 'hepatitis A'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2)

# %%
X_train.shape
# Out:
# (3944, 133)

# %%
X_test.shape
# Out:
# (986, 133)

# %%
# Convert labels to numbers
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
import xgboost as xgb

# Init classifier
model = xgb.XGBClassifier()

# Fit
model.fit(X_train, y_train)

# Predict
preds = model.predict(X_test)

# %%
le.inverse_transform(model.predict(X_test.iloc[1,:].to_numpy().reshape(1,-1)))
# Out:
# array(['Hepatitis B'], dtype=object)

# %%
y_data.cat.categories[1]
# Out:
# 'AIDS'

# %%
model.predict(X_test.iloc[2,:].to_numpy().reshape(1,-1))
# Out:
# array([14])

# %%
model.predict_proba(X_test.iloc[2,:].to_numpy().reshape(1,-1))[0,15]
# Out:
# 1.9084231e-05

# %%
accuracy_score(y_test, preds)
# Out:
# 1.0

# %%
y_test
# Out:
# array([ 2, 20, 14,  8,  6, 21, 27,  9, 34, 20, 40, 20, 19, 12, 35,  7, 22,
#         6, 13, 39, 10,  3, 13, 24, 15, 12, 26,  9, 13,  3, 19, 13, 40, 13,
#        37, 38,  6,  3, 34, 21, 27, 27,  9, 36,  0, 16, 31, 29, 41, 16,  6,
#        31, 16, 35, 14, 41, 32, 18,  8, 33, 19, 36, 20, 41, 38, 24, 39, 41,
#        37,  9, 16, 10, 34, 19, 39,  7, 23, 31, 14,  7, 29, 14, 41, 21, 18,
#        14, 16, 34, 25, 21, 28,  9,  3,  0, 30, 27, 10, 41, 40, 17, 20, 29,
#         4, 22, 15, 33, 39,  4, 21, 33, 32, 29, 37, 30, 39,  5,  0,  1, 21,
#         8, 40,  4, 34, 23, 17, 12,  4,  9, 37, 27, 12, 26, 37, 35,  0,  1,
#        19, 31,  9, 15, 27, 38, 24, 14, 19, 36, 14, 38, 28, 16, 32, 39, 21,
#         9, 19,  1, 24, 27, 20, 40, 40, 30, 34, 15, 38,  6, 19,  3, 39, 30,
#        23, 25, 38, 15,  0, 21, 24, 16, 24, 35, 21, 37, 32, 31, 31,  6, 31,
#        15, 24, 12, 26, 28, 39,  4, 12, 14, 32, 16, 10,  5, 12, 39, 39, 35,
#        32, 33,  7, 40,  7, 31, 29, 23, 30, 36, 22, 22, 29, 26, 35, 33, 13,
#        13, 31, 24, 35,  3, 34, 22,  6, 33, 40, 36, 21, 35, 30, 37,  6, 10,
#         8, 18,  6, 26, 40, 22, 34, 15, 23, 21, 13, 35, 40,  9, 39,  1,  3,
#        23, 35, 30,  3, 28,  5, 10,  8, 35,  5, 39, 39, 38, 22, 31, 38, 16,
#        25, 19, 35, 34,  3, 33, 24, 15,  0, 28, 38, 25, 22,  0, 14, 29, 19,
#        32,  8, 33, 39, 30, 38, 24,  0, 10,  4, 16,  4, 27, 24, 27, 32, 25,
#        12,  2, 23,  5, 19, 40, 34,  2, 26, 20,  0, 13, 34,  5, 28, 21, 18,
#        40, 25, 16, 15, 40, 37, 25, 26, 15,  0, 10,  9, 34, 15, 19, 33, 14,
#        28, 10, 25, 17, 39, 32, 10, 26, 12, 26, 16, 15,  5, 31, 30, 34, 21,
#        41, 12, 28, 37, 25, 40, 37, 32,  4, 29, 25, 30, 23,  9, 11, 32, 18,
#        40, 14, 25, 22, 41, 34, 24,  1, 24, 18, 26, 20, 23, 25, 21,  6, 15,
#        19, 20, 33,  8, 31, 28, 17, 29, 41, 20, 19, 26, 15, 13, 16,  4,  7,
#        34,  9, 34, 14, 22, 21, 30, 15, 20, 21,  5, 12,  9, 16, 34, 18,  6,
#         3,  3, 34,  2, 36,  7,  3, 33, 17, 28,  0, 39, 36,  3, 36, 41, 21,
#        29,  2, 12, 31, 34, 23,  9, 16, 29, 41, 20, 17, 22, 14, 40, 19, 41,
#         1,  2, 37, 41,  1,  3,  1, 22, 36, 41, 13, 18, 14,  6, 19, 37, 28,
#        15,  2, 38, 30, 34, 16, 36, 21, 14, 22, 41,  5,  1, 18, 21, 37, 14,
#        32, 19, 26, 28, 23, 17, 31, 20,  7, 18, 33, 13, 21, 40, 38,  4,  7,
#        24, 31, 36, 38, 31, 37, 39,  4, 34,  2, 36, 37, 15,  2,  6, 27, 20,
#        37, 14, 36, 19, 28,  3,  2, 31, 40, 16, 24, 19, 38, 17,  7, 28, 18,
#        30, 13, 16, 26, 27, 10,  3,  8, 38,  4, 12,  2, 39,  4, 14, 41,  2,
#        10, 39, 25, 10,  7, 19, 37, 38, 35, 36, 39, 35, 12, 33, 35, 33, 39,
#        22,  6, 28, 15, 13,  9, 30, 20, 21, 14,  2, 41, 27, 31, 13,  0, 34,
#         3, 36,  7, 39, 24, 25, 27, 30, 32, 14, 12,  7, 18, 25, 19,  0, 37,
#        24, 37,  2, 18, 39, 12, 26, 19, 38, 32,  5, 36,  4, 30, 30, 40, 17,
#        14, 35, 13, 32,  9, 17, 37, 12, 23, 10, 22, 37, 23, 24, 29, 19, 10,
#        40, 15,  4,  8, 28, 10, 12,  1, 30,  3, 20, 18,  8, 15, 38, 39, 21,
#        23, 14, 23,  9, 20, 29, 22, 10,  2, 10,  5, 22, 27, 27, 40, 22, 22,
#        39,  4, 27, 28, 35, 15, 17, 29, 23, 24, 33, 35,  6, 31, 40,  4, 33,
#         1, 32, 10,  9, 19, 25,  1, 13, 20, 29, 38, 40,  6, 20,  8, 22, 17,
#         0, 33,  1, 29, 30,  4,  8,  3, 31, 25,  2, 16, 22, 30, 36, 26, 33,
#        41, 13,  9, 28, 31, 12,  3,  5, 18, 21, 17, 24, 37, 31, 41, 24, 19,
#        31,  2,  0, 35, 35, 40, 24, 32,  8, 13,  6, 16, 33, 28, 32, 16,  9,
#         3,  1,  6, 12,  5, 15,  5, 15, 32, 40, 22,  0,  3, 34,  7, 21,  8,
#         3, 10, 32,  3, 15, 28,  6, 37, 13, 41,  5, 14, 16, 14, 10, 37,  1,
#         8, 36, 41, 24, 41, 32, 35, 39,  5, 25, 33,  7, 33,  1, 30, 33, 30,
#         8, 30, 16, 37, 15, 37, 28, 17, 24, 15,  4, 22, 12,  8,  4, 23, 22,
#        13, 26,  9,  2,  4, 18, 35, 30, 29, 19, 35, 10, 40, 20, 25, 14, 41,
#        41, 36,  4, 40, 19,  4, 15,  8,  4, 30, 12,  6,  0, 15, 27, 22, 40,
#        21,  5,  3,  8,  7, 29, 41, 29,  2, 25, 27, 14,  7,  5, 13, 12, 27,
#        37, 27,  1, 13, 18,  1, 15, 25, 34, 12, 29, 10,  7, 10, 33, 12, 21,
#        22, 24, 16, 34,  2, 12, 23, 23, 25,  0,  0, 25, 35, 38, 19, 22, 30,
#        38, 32, 41, 32,  6, 29,  1, 13, 38, 41,  2, 28, 17,  0, 29, 30,  9,
#        18, 30,  5, 17, 33, 24, 12,  1,  1, 16, 17, 16, 40,  1, 34,  0, 30,
#         4,  1, 28, 14, 27, 17, 10,  9, 10, 28,  1,  5, 32,  0, 26, 14,  8,
#        28, 10, 16, 39, 25, 27, 27, 16,  8,  0, 39, 25, 17, 38,  8, 26, 38])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        24
#            2       1.00      1.00      1.00        21
#            3       1.00      1.00      1.00        25
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        20
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        18
#            8       1.00      1.00      1.00        22
#            9       1.00      1.00      1.00        23
#           10       1.00      1.00      1.00        27
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00        27
#           13       1.00      1.00      1.00        24
#           14       1.00      1.00      1.00        28
#           15       1.00      1.00      1.00        29
#           16       1.00      1.00      1.00        28
#           17       1.00      1.00      1.00        19
#           18       1.00      1.00      1.00        18
#           19       1.00      1.00      1.00        28
#           20       1.00      1.00      1.00        20
#           21       1.00      1.00      1.00        26
#           22       1.00      1.00      1.00        27
#           23       1.00      1.00      1.00        19
#           24       1.00      1.00      1.00        26
#           25       1.00      1.00      1.00        25
#           26       1.00      1.00      1.00        18
#           27       1.00      1.00      1.00        23
#           28       1.00      1.00      1.00        25
#           29       1.00      1.00      1.00        22
#           30       1.00      1.00      1.00        29
#           31       1.00      1.00      1.00        23
#           32       1.00      1.00      1.00        24
#           33       1.00      1.00      1.00        24
#           34       1.00      1.00      1.00        26
#           35       1.00      1.00      1.00        24
#           36       1.00      1.00      1.00        19
#           37       1.00      1.00      1.00        27
#           38       1.00      1.00      1.00        24
#           39       1.00      1.00      1.00        28
#           40       1.00      1.00      1.00        29
#           41       1.00      1.00      1.00        27
#
#     accuracy                           1.00       986
#    macro avg       1.00      1.00      1.00       986
# weighted avg       1.00      1.00      1.00       986

# %%
y_data.cat.categories
# Out:
# Index(['(vertigo) Paroymsal  Positional Vertigo', 'AIDS', 'Acne',
#        'Alcoholic hepatitis', 'Allergy', 'Arthritis', 'Bronchial Asthma',
#        'Cervical spondylosis', 'Chicken pox', 'Chronic cholestasis',
#        'Common Cold', 'Covid', 'Dengue', 'Diabetes',
#        'Dimorphic hemmorhoids(piles)', 'Drug Reaction', 'Fungal infection',
#        'GERD', 'Gastroenteritis', 'Heart attack', 'Hepatitis B', 'Hepatitis C',
#        'Hepatitis D', 'Hepatitis E', 'Hypertension', 'Hyperthyroidism',
#        'Hypoglycemia', 'Hypothyroidism', 'Impetigo', 'Jaundice', 'Malaria',
#        'Migraine', 'Osteoarthristis', 'Paralysis (brain hemorrhage)',
#        'Peptic ulcer diseae', 'Pneumonia', 'Psoriasis', 'Tuberculosis',
#        'Typhoid', 'Urinary tract infection', 'Varicose veins', 'hepatitis A'],
#       dtype='object')

# %%
# import the dataset
desc_df = pd.read_csv('/content/disease_description.csv')

# %%
prec_df = pd.read_csv('/content/disease_precaution.csv')

# %%
prec_df[prec_df['Disease'] == 'Malaria'].filter(regex='Precaution').values.tolist()[0]
# Out:
# []
